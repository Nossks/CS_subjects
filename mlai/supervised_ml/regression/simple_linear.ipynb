# %%
import numpy as np;
import matplotlib.pyplot as plt;
import pandas as pd;

# %%
df=pd.read_csv("Salary_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df=df.drop("Unnamed: 0",axis=1);

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df[df.isnull()].count()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.scatter(df["YearsExperience"],df["Salary"])
plt.xlabel("years")
plt.ylabel("salary")
# Out:
# Text(0, 0.5, 'salary')

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
X=df[["YearsExperience"]]   #independent feature or input
y=df["Salary"]

# %%
from sklearn.model_selection import train_test_split;
X_Train,X_Test,y_Train,y_Test=train_test_split(X,y,test_size=.25,random_state=42)   #order matters

# %%
# standardistaion
from sklearn.preprocessing import StandardScaler;
scaler=StandardScaler()
X_Train=scaler.fit_transform(X_Train);
X_Test=scaler.transform(X_Test)

# %%
# select model
from sklearn.linear_model import LinearRegression;
regression=LinearRegression(n_jobs=-1)

# %%
model=regression.fit(X_Train,y_Train)

# %%
regression.coef_
# Out:
# array([25063.1519945])

# %%
plt.scatter(X_Train,y_Train)
plt.plot(X_Train,model.predict(X_Train))

# %%
y_predicted=model.predict(X_Test)

# %%
y_predicted
# Out:
# array([115440.88180109,  71397.10622651, 102321.45928951,  75145.51265839,
#         55466.37889103,  60151.88693088, 122000.59305688, 107006.96732936])

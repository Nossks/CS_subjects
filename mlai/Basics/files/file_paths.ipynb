# %%
import os
dir_name="test_folder"
os.mkdir(dir_name);
print(f"created `{dir_name}` package");
# Out:
# created `test_folder` package

# %%
lst=os.listdir(".");
print(lst)
# Out:
# ['test_folder', 'test.txt', 'file_handaling.ipynb', 'file_paths.ipynb']

# %%
relative_path="test.txt";
absolute_path=os.path.abspath(relative_path);
print(absolute_path);
# Out:
# /home/cry-more/machines_learning/files/test.txt

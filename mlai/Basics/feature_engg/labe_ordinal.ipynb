# %%
import pandas as pd;
df=pd.DataFrame({"members":["aryan","tushar","mumy","papa","aryan","tushar","mumy","papa"]})

# %%
df
# Out:
#   members
# 0   aryan
# 1  tushar
# 2    mumy
# 3    papa
# 4   aryan
# 5  tushar
# 6    mumy
# 7    papa

# %%
from sklearn.preprocessing import LabelEncoder;
lbl_encoder=LabelEncoder();

# %%
arr=pd.Series(lbl_encoder.fit_transform(df[["members"]]));
print(arr)
# Out:
# 0    0
# 1    3
# 2    1
# 3    2
# 4    0
# 5    3
# 6    1
# 7    2
# dtype: int64
# /home/cry-more/machines_learning/venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
arr.unique()
# Out:
# array([0, 3, 1, 2])

# %%
col=pd.Series(df["members"])

# %%
from sklearn.preprocessing import OrdinalEncoder;
oe=OrdinalEncoder(categories=[[name for name in col.unique()]]);

# %%
arr2=oe.fit_transform(df);

# %%
arr2
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [0.],
#        [1.],
#        [2.],
#        [3.]])

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
X,y=make_blobs(n_samples=1000,n_features=2,centers=4,random_state=13)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=3)

# %%
X_train.shape
# Out:
# (750, 2)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
X_train=scalar.fit_transform(X_train)
X_test=scalar.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.21815485, -1.5077046 ],
#        [-0.18514652, -1.56302927],
#        [ 0.72925454, -0.49882506],
#        ...,
#        [ 1.44467872, -0.58546527],
#        [ 1.09908594, -0.38614956],
#        [-0.94099071, -1.37784788]])

# %%
from sklearn.cluster import KMeans

wcss=[]
for k in range(1,11):
    k_mean=KMeans(n_clusters=k,init='k-means++',random_state=3)
    k_mean.fit(X_train)
    wcss.append(k_mean.inertia_)

wcss
# Out:
# [1500.0000000000005,
#  641.3061714280312,
#  397.6849008201773,
#  118.10727235947704,
#  102.98939268829807,
#  86.40120722458303,
#  68.66749174499427,
#  56.36819518627174,
#  52.48064983012239,
#  48.31117541577675]

# %% [markdown]
# ## Elbow Curve

# %%
plt.plot(range(1,11),wcss)
plt.title("elbow curve")
plt.xlabel("k vlaues")
plt.ylabel("wcss")
plt.show()

# %% [markdown]
# ## Other Technique

# %%
import os
import numpy as np
import cv2 as cv
from skimage.io import imread
from skimage.transform import resize

# %%
data=[]
label=[]
categories=["empty","not_empty"]
file_dir="/home/cry-more/cv/clf-data"

# %%
for index,category in enumerate(categories):
    for file_name in os.listdir(os.path.join(file_dir,category)):
        img_path=os.path.join(file_dir,category,file_name)
        img=cv.imread(img_path)
        img=resize(img,(15,15))
        data.append(img.flatten())
        label.append(index)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for index,category in enumerate(categories):
# ----> 2     for file_name in os.listdir(os.path.join(file_dir,category)):
#       3         img_path=os.path.join(file_dir,category,file_name)
#       4         img=cv.imread(img_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cry-more/cv/clf-data/empty'

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,label,test_size=.20,shuffle=True,random_state=3,stratify=label)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
`qfrom sklearn.svm import SVC 
model=SVC()

from sklearn.model_selection import GridSearchCV
para={
    'gamma': [0.01, 0.001, 0.0001],
    'C': [1, 10, 100, 1000]
}

random=GridSearchCV(estimator=model,param_grid=para,verbose=1)
random.fit(X_train,y_train)


print(random.best_params_)

y_pred=random.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))

# %%
import os
import pickle

from skimage.io import imread
from skimage.transform import resize
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


# prepare data
input_dir = '/home/cry-more/cs/cv/clf-data'
categories = ['empty', 'not_empty']

data = []
labels = []
for category_idx, category in enumerate(categories):
    for file in os.listdir(os.path.join(input_dir, category)):
        img_path = os.path.join(input_dir, category, file)
        img = imread(img_path)
        img = resize(img, (15, 15))
        data.append(img.flatten())
        labels.append(category_idx)

data = np.asarray(data)
labels = np.asarray(labels)

# train / test split
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, stratify=labels)

# train classifier
classifier = SVC()

parameters = [{'gamma': [0.01, 0.001, 0.0001], 'C': [1, 10, 100, 1000]}]

grid_search = GridSearchCV(classifier, parameters,verbose=1,cv=5)

grid_search.fit(x_train, y_train)

# test performance
best_estimator = grid_search.best_estimator_

y_prediction = best_estimator.predict(x_test)

score = accuracy_score(y_test,y_prediction)

print('{}% of samples were correctly classified'.format(str(score * 100)))

pickle.dump(best_estimator, open('./model.p', 'wb'))

# %%
score = accuracy_score(y_test,y_prediction)
print('{}% of samples were correctly classified'.format(str(score * 100)))
